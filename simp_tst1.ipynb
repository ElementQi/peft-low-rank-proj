# %%
from ct_model import DeltaModel, dispatch_default
from ct_bnb import Linear4bit, dispatch_bnb_4bit
from ct_layer import DeltaLayer
from ct_config import CTConfig
from block_optim import BlockOptimizer
from prepare_data import gen_dataloader

from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
import torch
# Out:
# /home/ubuntu/date/mq_tst/anaconda3/envs/newpeft/lib/python3.10/site-packages/transformers/utils/hub.py:124: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
import os
os.environ['HF_HOME'] = '/home/ubuntu/date/hf_cache'

os.environ['HTTP_PROXY'] = "http://10.24.59.12:7890"
os.environ['HTTPS_PROXY'] = "http://10.24.59.12:7890"

# %%
device_id = 2

# Quantization type (fp4 or nf4), According to QLoRA paper, for training 4-bit base models (e.g. using LoRA adapters) one should use
bnb_4bit_quant_type = "fp4"

# Activate nested quantization for 4-bit base models (double quantization)
use_nested_quant = True

model_id = "Qwen/Qwen1.5-0.5B"
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=use_nested_quant,
    bnb_4bit_quant_type=bnb_4bit_quant_type,
    bnb_4bit_compute_dtype=torch.bfloat16
)

tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id, quantization_config=bnb_config, device_map={"":device_id})
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
config = CTConfig(
             r=32,
             delta_alpha=1,
             target_modules=["q_proj", "k_proj", "v_proj", "o_proj",
                             "gate_proj", "up_proj", "down_proj"],
             delta_dropout=0,
             init_lora_weights=False,
         )

# %%
delta_model = DeltaModel(model, config, "default")

# %%
def apply_to_innermost_layers(module, operation, prefix=''):
    """
    Recursively traverse all submodules of a model and apply a specific operation
    to the innermost layers, passing the full name of the layer.
    """
    has_children = False
    for name, layer in module.named_children():
        has_children = True
        new_prefix = f"{prefix}.{name}" if prefix else name
        apply_to_innermost_layers(layer, operation, new_prefix)
    
    # If the module has no children, it's an innermost layer
    if not has_children:
        
        # operation(module, prefix)
        # here we can get the name info
        inner_module = prefix.split(".")[-1] # like delta_theta, delta_A
        print(prefix.split(".")[-1])

# %%
apply_to_innermost_layers(delta_model, None)
# Out:
# embed_tokens
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# rotary_emb
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# act_fn
# input_layernorm
# post_attention_layernorm
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# rotary_emb
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# act_fn
# input_layernorm
# post_attention_layernorm
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# rotary_emb
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# act_fn
# input_layernorm
# post_attention_layernorm
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# rotary_emb
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# act_fn
# input_layernorm
# post_attention_layernorm
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# rotary_emb
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# act_fn
# input_layernorm
# post_attention_layernorm
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# rotary_emb
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# act_fn
# input_layernorm
# post_attention_layernorm
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# rotary_emb
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# act_fn
# input_layernorm
# post_attention_layernorm
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# rotary_emb
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# act_fn
# input_layernorm
# post_attention_layernorm
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# rotary_emb
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# act_fn
# input_layernorm
# post_attention_layernorm
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# rotary_emb
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# act_fn
# input_layernorm
# post_attention_layernorm
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# rotary_emb
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# act_fn
# input_layernorm
# post_attention_layernorm
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# rotary_emb
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# act_fn
# input_layernorm
# post_attention_layernorm
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# rotary_emb
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# act_fn
# input_layernorm
# post_attention_layernorm
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# rotary_emb
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# act_fn
# input_layernorm
# post_attention_layernorm
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# rotary_emb
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# act_fn
# input_layernorm
# post_attention_layernorm
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# rotary_emb
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# act_fn
# input_layernorm
# post_attention_layernorm
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# rotary_emb
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# act_fn
# input_layernorm
# post_attention_layernorm
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# rotary_emb
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# act_fn
# input_layernorm
# post_attention_layernorm
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# rotary_emb
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# act_fn
# input_layernorm
# post_attention_layernorm
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# rotary_emb
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# act_fn
# input_layernorm
# post_attention_layernorm
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# rotary_emb
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# act_fn
# input_layernorm
# post_attention_layernorm
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# rotary_emb
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# act_fn
# input_layernorm
# post_attention_layernorm
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# rotary_emb
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# act_fn
# input_layernorm
# post_attention_layernorm
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# rotary_emb
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# base_layer
# default
# delta_theta
# delta_A
# delta_B
# delta_embedding
# act_fn
# input_layernorm
# post_attention_layernorm
# norm
# lm_head

# %%
for n, p in delta_model.named_parameters():
    if "lora" in n:
        print(n)

# %%
def infer_param_groups(named_parameters_list, include_embedding=False, include_lm_head=False):
    """automatic inference of the parameter groups based on the parameter names.
    divide groups into:
        * embedding
        * transformer layers
        * lm_head and others
    """
    import re
    
    block_prefix_list = []
    lm_head_and_other_params = []
    embed_pattern = r'.*embed[^.]*\.'
    layer_pattern = r'.*layers.[^.]*\.'

    param_names = [n for n, _ in named_parameters_list]
    for name in param_names:
        if any(prefix[0] in name for prefix in block_prefix_list):
            continue
        
        if re.findall(layer_pattern, name):
            block_prefix_list.append(re.findall(layer_pattern, name))
        elif re.findall(embed_pattern, name) and include_embedding:
            block_prefix_list.append(re.findall(embed_pattern, name))
        else:
            lm_head_and_other_params.append(name)
    
    if include_lm_head:
        block_prefix_list.append(lm_head_and_other_params)
    
    return block_prefix_list

# %%
infer_param_groups(list(delta_model.named_parameters()))
# Out:
# [['model.model.layers.0.'],
#  ['model.model.layers.1.'],
#  ['model.model.layers.2.'],
#  ['model.model.layers.3.'],
#  ['model.model.layers.4.'],
#  ['model.model.layers.5.'],
#  ['model.model.layers.6.'],
#  ['model.model.layers.7.'],
#  ['model.model.layers.8.'],
#  ['model.model.layers.9.'],
#  ['model.model.layers.10.'],
#  ['model.model.layers.11.'],
#  ['model.model.layers.12.'],
#  ['model.model.layers.13.'],
#  ['model.model.layers.14.'],
#  ['model.model.layers.15.'],
#  ['model.model.layers.16.'],
#  ['model.model.layers.17.'],
#  ['model.model.layers.18.'],
#  ['model.model.layers.19.'],
#  ['model.model.layers.20.'],
#  ['model.model.layers.21.'],
#  ['model.model.layers.22.'],
#  ['model.model.layers.23.']]

# %%
model.model.layers[0].self_attn.q_proj
# Out:
# lora.Linear4bit(
#   (base_layer): Linear4bit(in_features=1024, out_features=1024, bias=True)
#   (delta_dropout): ModuleDict(
#     (default): Identity()
#   )
#   (delta_theta): ModuleDict()
#   (delta_A): ModuleDict()
#   (delta_B): ModuleDict()
#   (delta_embedding): ParameterDict()
# )

# %%
prefix = "model.model.layers.0.self_attn.q_proj.delta_A"

# %%
layer_num = prefix.split(".")[3]
layer_prefix = ".".join(prefix.split(".")[:3])
attention_name = ".".join(prefix.split(".")[-3:-1])
the_layer = eval( f"{layer_prefix}[{layer_num}].{attention_name}" )

# %%
the_layer
# Out:
# lora.Linear4bit(
#   (base_layer): Linear4bit(in_features=1024, out_features=1024, bias=True)
#   (delta_dropout): ModuleDict(
#     (default): Identity()
#   )
#   (delta_theta): ModuleDict()
#   (delta_A): ModuleDict()
#   (delta_B): ModuleDict()
#   (delta_embedding): ParameterDict()
# )

# %%
"model.model.layers.0." in "model.model.layers.0.self_attn.q_proj.base_layer"
# Out:
# True

# %%
dataloader = gen_dataloader(tokenizer)
# Out:
# Map (num_proc=4):   0%|          | 0/800 [00:00<?, ? examples/s]
# Map (num_proc=4):   0%|          | 0/200 [00:00<?, ? examples/s]
# Map (num_proc=4):   0%|          | 0/800 [00:00<?, ? examples/s]
# Map (num_proc=4):   0%|          | 0/200 [00:00<?, ? examples/s]

# %%
delta_model
# Out:
# DeltaModel(
#   (model): Qwen2ForCausalLM(
#     (model): Qwen2Model(
#       (embed_tokens): Embedding(151936, 1024)
#       (layers): ModuleList(
#         (0-23): 24 x Qwen2DecoderLayer(
#           (self_attn): Qwen2SdpaAttention(
#             (q_proj): lora.Linear4bit(
#               (base_layer): Linear4bit(in_features=1024, out_features=1024, bias=True)
#               (delta_dropout): ModuleDict(
#                 (default): Identity()
#               )
#               (delta_theta): ModuleDict()
#               (delta_A): ModuleDict()
#               (delta_B): ModuleDict()
#               (delta_embedding): ParameterDict()
#             )
#             (k_proj): lora.Linear4bit(
#               (base_layer): Linear4bit(in_features=1024, out_features=1024, bias=True)
#               (delta_dropout): ModuleDict(
#                 (default): Identity()
#               )
#               (delta_theta): ModuleDict()
#               (delta_A): ModuleDict()
#               (delta_B): ModuleDict()
#               (delta_embedding): ParameterDict()
#             )
#             (v_proj): lora.Linear4bit(
#               (base_layer): Linear4bit(in_features=1024, out_features=1024, bias=True)
#               (delta_dropout): ModuleDict(
#                 (default): Identity()
#               )
#               (delta_theta): ModuleDict()
#               (delta_A): ModuleDict()
#               (delta_B): ModuleDict()
#               (delta_embedding): ParameterDict()
#             )
#             (o_proj): lora.Linear4bit(
#               (base_layer): Linear4bit(in_features=1024, out_features=1024, bias=False)
#               (delta_dropout): ModuleDict(
#                 (default): Identity()
#               )
#               (delta_theta): ModuleDict()
#               (delta_A): ModuleDict()
#               (delta_B): ModuleDict()
#               (delta_embedding): ParameterDict()
#             )
#             (rotary_emb): Qwen2RotaryEmbedding()
#           )
#           (mlp): Qwen2MLP(
#             (gate_proj): lora.Linear4bit(
#               (base_layer): Linear4bit(in_features=1024, out_features=2816, bias=False)
#               (delta_dropout): ModuleDict(
#                 (default): Identity()
#               )
#               (delta_theta): ModuleDict()
#               (delta_A): ModuleDict()
#               (delta_B): ModuleDict()
#               (delta_embedding): ParameterDict()
#             )
#             (up_proj): lora.Linear4bit(
#               (base_layer): Linear4bit(in_features=1024, out_features=2816, bias=False)
#               (delta_dropout): ModuleDict(
#                 (default): Identity()
#               )
#               (delta_theta): ModuleDict()
#               (delta_A): ModuleDict()
#               (delta_B): ModuleDict()
#               (delta_embedding): ParameterDict()
#             )
#             (down_proj): lora.Linear4bit(
#               (base_layer): Linear4bit(in_features=2816, out_features=1024, bias=False)
#               (delta_dropout): ModuleDict(
#                 (default): Identity()
#               )
#               (delta_theta): ModuleDict()
#               (delta_A): ModuleDict()
#               (delta_B): ModuleDict()
#               (delta_embedding): ParameterDict()
#             )
#             (act_fn): SiLU()
#           )
#           (input_layernorm): Qwen2RMSNorm()
#           (post_attention_layernorm): Qwen2RMSNorm()
#         )
#       )
#       (norm): Qwen2RMSNorm()
#     )
#     (lm_head): Linear(in_features=1024, out_features=151936, bias=False)
#   )
# )

# %%
def apply_to_innermost_layers(module, operation, prefix=''):
    """
    Recursively traverse all submodules of a model and apply a specific operation
    to the innermost layers, passing the full name of the layer.
    """
    has_children = False
    for name, layer in module.named_children():
        has_children = True
        new_prefix = f"{prefix}.{name}" if prefix else name
        apply_to_innermost_layers(layer, operation, new_prefix)
    
    # If the module has no children, it's an innermost layer
    if not has_children:
        # operation(module, prefix)
        print(prefix)

# Define the operation you want to perform on each innermost layer
# def my_operation(layer, layer_name):
#     print(f"Applying operation to innermost layer: {layer_name} ({type(layer)})")
#     # Example operation: print layer weights if it's a Linear layer
#     if isinstance(layer, nn.Linear):
#         print(f"Layer weights: {layer.weight}")

# %%
apply_to_innermost_layers(delta_model, None)
# Out:
# model.model.embed_tokens
# model.model.layers.0.self_attn.q_proj.base_layer
# model.model.layers.0.self_attn.q_proj.delta_dropout.default
# model.model.layers.0.self_attn.q_proj.delta_theta
# model.model.layers.0.self_attn.q_proj.delta_A
# model.model.layers.0.self_attn.q_proj.delta_B
# model.model.layers.0.self_attn.q_proj.delta_embedding
# model.model.layers.0.self_attn.k_proj.base_layer
# model.model.layers.0.self_attn.k_proj.delta_dropout.default
# model.model.layers.0.self_attn.k_proj.delta_theta
# model.model.layers.0.self_attn.k_proj.delta_A
# model.model.layers.0.self_attn.k_proj.delta_B
# model.model.layers.0.self_attn.k_proj.delta_embedding
# model.model.layers.0.self_attn.v_proj.base_layer
# model.model.layers.0.self_attn.v_proj.delta_dropout.default
# model.model.layers.0.self_attn.v_proj.delta_theta
# model.model.layers.0.self_attn.v_proj.delta_A
# model.model.layers.0.self_attn.v_proj.delta_B
# model.model.layers.0.self_attn.v_proj.delta_embedding
# model.model.layers.0.self_attn.o_proj.base_layer
# model.model.layers.0.self_attn.o_proj.delta_dropout.default
# model.model.layers.0.self_attn.o_proj.delta_theta
# model.model.layers.0.self_attn.o_proj.delta_A
# model.model.layers.0.self_attn.o_proj.delta_B
# model.model.layers.0.self_attn.o_proj.delta_embedding
# model.model.layers.0.self_attn.rotary_emb
# model.model.layers.0.mlp.gate_proj.base_layer
# model.model.layers.0.mlp.gate_proj.delta_dropout.default
# model.model.layers.0.mlp.gate_proj.delta_theta
# model.model.layers.0.mlp.gate_proj.delta_A
# model.model.layers.0.mlp.gate_proj.delta_B
# model.model.layers.0.mlp.gate_proj.delta_embedding
# model.model.layers.0.mlp.up_proj.base_layer
# model.model.layers.0.mlp.up_proj.delta_dropout.default
# model.model.layers.0.mlp.up_proj.delta_theta
# model.model.layers.0.mlp.up_proj.delta_A
# model.model.layers.0.mlp.up_proj.delta_B
# model.model.layers.0.mlp.up_proj.delta_embedding
# model.model.layers.0.mlp.down_proj.base_layer
# model.model.layers.0.mlp.down_proj.delta_dropout.default
# model.model.layers.0.mlp.down_proj.delta_theta
# model.model.layers.0.mlp.down_proj.delta_A
# model.model.layers.0.mlp.down_proj.delta_B
# model.model.layers.0.mlp.down_proj.delta_embedding
# model.model.layers.0.mlp.act_fn
# model.model.layers.0.input_layernorm
# model.model.layers.0.post_attention_layernorm
# model.model.layers.1.self_attn.q_proj.base_layer
# model.model.layers.1.self_attn.q_proj.delta_dropout.default
# model.model.layers.1.self_attn.q_proj.delta_theta
# model.model.layers.1.self_attn.q_proj.delta_A
# model.model.layers.1.self_attn.q_proj.delta_B
# model.model.layers.1.self_attn.q_proj.delta_embedding
# model.model.layers.1.self_attn.k_proj.base_layer
# model.model.layers.1.self_attn.k_proj.delta_dropout.default
# model.model.layers.1.self_attn.k_proj.delta_theta
# model.model.layers.1.self_attn.k_proj.delta_A
# model.model.layers.1.self_attn.k_proj.delta_B
# model.model.layers.1.self_attn.k_proj.delta_embedding
# model.model.layers.1.self_attn.v_proj.base_layer
# model.model.layers.1.self_attn.v_proj.delta_dropout.default
# model.model.layers.1.self_attn.v_proj.delta_theta
# model.model.layers.1.self_attn.v_proj.delta_A
# model.model.layers.1.self_attn.v_proj.delta_B
# model.model.layers.1.self_attn.v_proj.delta_embedding
# model.model.layers.1.self_attn.o_proj.base_layer
# model.model.layers.1.self_attn.o_proj.delta_dropout.default
# model.model.layers.1.self_attn.o_proj.delta_theta
# model.model.layers.1.self_attn.o_proj.delta_A
# model.model.layers.1.self_attn.o_proj.delta_B
# model.model.layers.1.self_attn.o_proj.delta_embedding
# model.model.layers.1.self_attn.rotary_emb
# model.model.layers.1.mlp.gate_proj.base_layer
# model.model.layers.1.mlp.gate_proj.delta_dropout.default
# model.model.layers.1.mlp.gate_proj.delta_theta
# model.model.layers.1.mlp.gate_proj.delta_A
# model.model.layers.1.mlp.gate_proj.delta_B
# model.model.layers.1.mlp.gate_proj.delta_embedding
# model.model.layers.1.mlp.up_proj.base_layer
# model.model.layers.1.mlp.up_proj.delta_dropout.default
# model.model.layers.1.mlp.up_proj.delta_theta
# model.model.layers.1.mlp.up_proj.delta_A
# model.model.layers.1.mlp.up_proj.delta_B
# model.model.layers.1.mlp.up_proj.delta_embedding
# model.model.layers.1.mlp.down_proj.base_layer
# model.model.layers.1.mlp.down_proj.delta_dropout.default
# model.model.layers.1.mlp.down_proj.delta_theta
# model.model.layers.1.mlp.down_proj.delta_A
# model.model.layers.1.mlp.down_proj.delta_B
# model.model.layers.1.mlp.down_proj.delta_embedding
# model.model.layers.1.mlp.act_fn
# model.model.layers.1.input_layernorm
# model.model.layers.1.post_attention_layernorm
# model.model.layers.2.self_attn.q_proj.base_layer
# model.model.layers.2.self_attn.q_proj.delta_dropout.default
# model.model.layers.2.self_attn.q_proj.delta_theta
# model.model.layers.2.self_attn.q_proj.delta_A
# model.model.layers.2.self_attn.q_proj.delta_B
# model.model.layers.2.self_attn.q_proj.delta_embedding
# model.model.layers.2.self_attn.k_proj.base_layer
# model.model.layers.2.self_attn.k_proj.delta_dropout.default
# model.model.layers.2.self_attn.k_proj.delta_theta
# model.model.layers.2.self_attn.k_proj.delta_A
# model.model.layers.2.self_attn.k_proj.delta_B
# model.model.layers.2.self_attn.k_proj.delta_embedding
# model.model.layers.2.self_attn.v_proj.base_layer
# model.model.layers.2.self_attn.v_proj.delta_dropout.default
# model.model.layers.2.self_attn.v_proj.delta_theta
# model.model.layers.2.self_attn.v_proj.delta_A
# model.model.layers.2.self_attn.v_proj.delta_B
# model.model.layers.2.self_attn.v_proj.delta_embedding
# model.model.layers.2.self_attn.o_proj.base_layer
# model.model.layers.2.self_attn.o_proj.delta_dropout.default
# model.model.layers.2.self_attn.o_proj.delta_theta
# model.model.layers.2.self_attn.o_proj.delta_A
# model.model.layers.2.self_attn.o_proj.delta_B
# model.model.layers.2.self_attn.o_proj.delta_embedding
# model.model.layers.2.self_attn.rotary_emb
# model.model.layers.2.mlp.gate_proj.base_layer
# model.model.layers.2.mlp.gate_proj.delta_dropout.default
# model.model.layers.2.mlp.gate_proj.delta_theta
# model.model.layers.2.mlp.gate_proj.delta_A
# model.model.layers.2.mlp.gate_proj.delta_B
# model.model.layers.2.mlp.gate_proj.delta_embedding
# model.model.layers.2.mlp.up_proj.base_layer
# model.model.layers.2.mlp.up_proj.delta_dropout.default
# model.model.layers.2.mlp.up_proj.delta_theta
# model.model.layers.2.mlp.up_proj.delta_A
# model.model.layers.2.mlp.up_proj.delta_B
# model.model.layers.2.mlp.up_proj.delta_embedding
# model.model.layers.2.mlp.down_proj.base_layer
# model.model.layers.2.mlp.down_proj.delta_dropout.default
# model.model.layers.2.mlp.down_proj.delta_theta
# model.model.layers.2.mlp.down_proj.delta_A
# model.model.layers.2.mlp.down_proj.delta_B
# model.model.layers.2.mlp.down_proj.delta_embedding
# model.model.layers.2.mlp.act_fn
# model.model.layers.2.input_layernorm
# model.model.layers.2.post_attention_layernorm
# model.model.layers.3.self_attn.q_proj.base_layer
# model.model.layers.3.self_attn.q_proj.delta_dropout.default
# model.model.layers.3.self_attn.q_proj.delta_theta
# model.model.layers.3.self_attn.q_proj.delta_A
# model.model.layers.3.self_attn.q_proj.delta_B
# model.model.layers.3.self_attn.q_proj.delta_embedding
# model.model.layers.3.self_attn.k_proj.base_layer
# model.model.layers.3.self_attn.k_proj.delta_dropout.default
# model.model.layers.3.self_attn.k_proj.delta_theta
# model.model.layers.3.self_attn.k_proj.delta_A
# model.model.layers.3.self_attn.k_proj.delta_B
# model.model.layers.3.self_attn.k_proj.delta_embedding
# model.model.layers.3.self_attn.v_proj.base_layer
# model.model.layers.3.self_attn.v_proj.delta_dropout.default
# model.model.layers.3.self_attn.v_proj.delta_theta
# model.model.layers.3.self_attn.v_proj.delta_A
# model.model.layers.3.self_attn.v_proj.delta_B
# model.model.layers.3.self_attn.v_proj.delta_embedding
# model.model.layers.3.self_attn.o_proj.base_layer
# model.model.layers.3.self_attn.o_proj.delta_dropout.default
# model.model.layers.3.self_attn.o_proj.delta_theta
# model.model.layers.3.self_attn.o_proj.delta_A
# model.model.layers.3.self_attn.o_proj.delta_B
# model.model.layers.3.self_attn.o_proj.delta_embedding
# model.model.layers.3.self_attn.rotary_emb
# model.model.layers.3.mlp.gate_proj.base_layer
# model.model.layers.3.mlp.gate_proj.delta_dropout.default
# model.model.layers.3.mlp.gate_proj.delta_theta
# model.model.layers.3.mlp.gate_proj.delta_A
# model.model.layers.3.mlp.gate_proj.delta_B
# model.model.layers.3.mlp.gate_proj.delta_embedding
# model.model.layers.3.mlp.up_proj.base_layer
# model.model.layers.3.mlp.up_proj.delta_dropout.default
# model.model.layers.3.mlp.up_proj.delta_theta
# model.model.layers.3.mlp.up_proj.delta_A
# model.model.layers.3.mlp.up_proj.delta_B
# model.model.layers.3.mlp.up_proj.delta_embedding
# model.model.layers.3.mlp.down_proj.base_layer
# model.model.layers.3.mlp.down_proj.delta_dropout.default
# model.model.layers.3.mlp.down_proj.delta_theta
# model.model.layers.3.mlp.down_proj.delta_A
# model.model.layers.3.mlp.down_proj.delta_B
# model.model.layers.3.mlp.down_proj.delta_embedding
# model.model.layers.3.mlp.act_fn
# model.model.layers.3.input_layernorm
# model.model.layers.3.post_attention_layernorm
# model.model.layers.4.self_attn.q_proj.base_layer
# model.model.layers.4.self_attn.q_proj.delta_dropout.default
# model.model.layers.4.self_attn.q_proj.delta_theta
# model.model.layers.4.self_attn.q_proj.delta_A
# model.model.layers.4.self_attn.q_proj.delta_B
# model.model.layers.4.self_attn.q_proj.delta_embedding
# model.model.layers.4.self_attn.k_proj.base_layer
# model.model.layers.4.self_attn.k_proj.delta_dropout.default
# model.model.layers.4.self_attn.k_proj.delta_theta
# model.model.layers.4.self_attn.k_proj.delta_A
# model.model.layers.4.self_attn.k_proj.delta_B
# model.model.layers.4.self_attn.k_proj.delta_embedding
# model.model.layers.4.self_attn.v_proj.base_layer
# model.model.layers.4.self_attn.v_proj.delta_dropout.default
# model.model.layers.4.self_attn.v_proj.delta_theta
# model.model.layers.4.self_attn.v_proj.delta_A
# model.model.layers.4.self_attn.v_proj.delta_B
# model.model.layers.4.self_attn.v_proj.delta_embedding
# model.model.layers.4.self_attn.o_proj.base_layer
# model.model.layers.4.self_attn.o_proj.delta_dropout.default
# model.model.layers.4.self_attn.o_proj.delta_theta
# model.model.layers.4.self_attn.o_proj.delta_A
# model.model.layers.4.self_attn.o_proj.delta_B
# model.model.layers.4.self_attn.o_proj.delta_embedding
# model.model.layers.4.self_attn.rotary_emb
# model.model.layers.4.mlp.gate_proj.base_layer
# model.model.layers.4.mlp.gate_proj.delta_dropout.default
# model.model.layers.4.mlp.gate_proj.delta_theta
# model.model.layers.4.mlp.gate_proj.delta_A
# model.model.layers.4.mlp.gate_proj.delta_B
# model.model.layers.4.mlp.gate_proj.delta_embedding
# model.model.layers.4.mlp.up_proj.base_layer
# model.model.layers.4.mlp.up_proj.delta_dropout.default
# model.model.layers.4.mlp.up_proj.delta_theta
# model.model.layers.4.mlp.up_proj.delta_A
# model.model.layers.4.mlp.up_proj.delta_B
# model.model.layers.4.mlp.up_proj.delta_embedding
# model.model.layers.4.mlp.down_proj.base_layer
# model.model.layers.4.mlp.down_proj.delta_dropout.default
# model.model.layers.4.mlp.down_proj.delta_theta
# model.model.layers.4.mlp.down_proj.delta_A
# model.model.layers.4.mlp.down_proj.delta_B
# model.model.layers.4.mlp.down_proj.delta_embedding
# model.model.layers.4.mlp.act_fn
# model.model.layers.4.input_layernorm
# model.model.layers.4.post_attention_layernorm
# model.model.layers.5.self_attn.q_proj.base_layer
# model.model.layers.5.self_attn.q_proj.delta_dropout.default
# model.model.layers.5.self_attn.q_proj.delta_theta
# model.model.layers.5.self_attn.q_proj.delta_A
# model.model.layers.5.self_attn.q_proj.delta_B
# model.model.layers.5.self_attn.q_proj.delta_embedding
# model.model.layers.5.self_attn.k_proj.base_layer
# model.model.layers.5.self_attn.k_proj.delta_dropout.default
# model.model.layers.5.self_attn.k_proj.delta_theta
# model.model.layers.5.self_attn.k_proj.delta_A
# model.model.layers.5.self_attn.k_proj.delta_B
# model.model.layers.5.self_attn.k_proj.delta_embedding
# model.model.layers.5.self_attn.v_proj.base_layer
# model.model.layers.5.self_attn.v_proj.delta_dropout.default
# model.model.layers.5.self_attn.v_proj.delta_theta
# model.model.layers.5.self_attn.v_proj.delta_A
# model.model.layers.5.self_attn.v_proj.delta_B
# model.model.layers.5.self_attn.v_proj.delta_embedding
# model.model.layers.5.self_attn.o_proj.base_layer
# model.model.layers.5.self_attn.o_proj.delta_dropout.default
# model.model.layers.5.self_attn.o_proj.delta_theta
# model.model.layers.5.self_attn.o_proj.delta_A
# model.model.layers.5.self_attn.o_proj.delta_B
# model.model.layers.5.self_attn.o_proj.delta_embedding
# model.model.layers.5.self_attn.rotary_emb
# model.model.layers.5.mlp.gate_proj.base_layer
# model.model.layers.5.mlp.gate_proj.delta_dropout.default
# model.model.layers.5.mlp.gate_proj.delta_theta
# model.model.layers.5.mlp.gate_proj.delta_A
# model.model.layers.5.mlp.gate_proj.delta_B
# model.model.layers.5.mlp.gate_proj.delta_embedding
# model.model.layers.5.mlp.up_proj.base_layer
# model.model.layers.5.mlp.up_proj.delta_dropout.default
# model.model.layers.5.mlp.up_proj.delta_theta
# model.model.layers.5.mlp.up_proj.delta_A
# model.model.layers.5.mlp.up_proj.delta_B
# model.model.layers.5.mlp.up_proj.delta_embedding
# model.model.layers.5.mlp.down_proj.base_layer
# model.model.layers.5.mlp.down_proj.delta_dropout.default
# model.model.layers.5.mlp.down_proj.delta_theta
# model.model.layers.5.mlp.down_proj.delta_A
# model.model.layers.5.mlp.down_proj.delta_B
# model.model.layers.5.mlp.down_proj.delta_embedding
# model.model.layers.5.mlp.act_fn
# model.model.layers.5.input_layernorm
# model.model.layers.5.post_attention_layernorm
# model.model.layers.6.self_attn.q_proj.base_layer
# model.model.layers.6.self_attn.q_proj.delta_dropout.default
# model.model.layers.6.self_attn.q_proj.delta_theta
# model.model.layers.6.self_attn.q_proj.delta_A
# model.model.layers.6.self_attn.q_proj.delta_B
# model.model.layers.6.self_attn.q_proj.delta_embedding
# model.model.layers.6.self_attn.k_proj.base_layer
# model.model.layers.6.self_attn.k_proj.delta_dropout.default
# model.model.layers.6.self_attn.k_proj.delta_theta
# model.model.layers.6.self_attn.k_proj.delta_A
# model.model.layers.6.self_attn.k_proj.delta_B
# model.model.layers.6.self_attn.k_proj.delta_embedding
# model.model.layers.6.self_attn.v_proj.base_layer
# model.model.layers.6.self_attn.v_proj.delta_dropout.default
# model.model.layers.6.self_attn.v_proj.delta_theta
# model.model.layers.6.self_attn.v_proj.delta_A
# model.model.layers.6.self_attn.v_proj.delta_B
# model.model.layers.6.self_attn.v_proj.delta_embedding
# model.model.layers.6.self_attn.o_proj.base_layer
# model.model.layers.6.self_attn.o_proj.delta_dropout.default
# model.model.layers.6.self_attn.o_proj.delta_theta
# model.model.layers.6.self_attn.o_proj.delta_A
# model.model.layers.6.self_attn.o_proj.delta_B
# model.model.layers.6.self_attn.o_proj.delta_embedding
# model.model.layers.6.self_attn.rotary_emb
# model.model.layers.6.mlp.gate_proj.base_layer
# model.model.layers.6.mlp.gate_proj.delta_dropout.default
# model.model.layers.6.mlp.gate_proj.delta_theta
# model.model.layers.6.mlp.gate_proj.delta_A
# model.model.layers.6.mlp.gate_proj.delta_B
# model.model.layers.6.mlp.gate_proj.delta_embedding
# model.model.layers.6.mlp.up_proj.base_layer
# model.model.layers.6.mlp.up_proj.delta_dropout.default
# model.model.layers.6.mlp.up_proj.delta_theta
# model.model.layers.6.mlp.up_proj.delta_A
# model.model.layers.6.mlp.up_proj.delta_B
# model.model.layers.6.mlp.up_proj.delta_embedding
# model.model.layers.6.mlp.down_proj.base_layer
# model.model.layers.6.mlp.down_proj.delta_dropout.default
# model.model.layers.6.mlp.down_proj.delta_theta
# model.model.layers.6.mlp.down_proj.delta_A
# model.model.layers.6.mlp.down_proj.delta_B
# model.model.layers.6.mlp.down_proj.delta_embedding
# model.model.layers.6.mlp.act_fn
# model.model.layers.6.input_layernorm
# model.model.layers.6.post_attention_layernorm
# model.model.layers.7.self_attn.q_proj.base_layer
# model.model.layers.7.self_attn.q_proj.delta_dropout.default
# model.model.layers.7.self_attn.q_proj.delta_theta
# model.model.layers.7.self_attn.q_proj.delta_A
# model.model.layers.7.self_attn.q_proj.delta_B
# model.model.layers.7.self_attn.q_proj.delta_embedding
# model.model.layers.7.self_attn.k_proj.base_layer
# model.model.layers.7.self_attn.k_proj.delta_dropout.default
# model.model.layers.7.self_attn.k_proj.delta_theta
# model.model.layers.7.self_attn.k_proj.delta_A
# model.model.layers.7.self_attn.k_proj.delta_B
# model.model.layers.7.self_attn.k_proj.delta_embedding
# model.model.layers.7.self_attn.v_proj.base_layer
# model.model.layers.7.self_attn.v_proj.delta_dropout.default
# model.model.layers.7.self_attn.v_proj.delta_theta
# model.model.layers.7.self_attn.v_proj.delta_A
# model.model.layers.7.self_attn.v_proj.delta_B
# model.model.layers.7.self_attn.v_proj.delta_embedding
# model.model.layers.7.self_attn.o_proj.base_layer
# model.model.layers.7.self_attn.o_proj.delta_dropout.default
# model.model.layers.7.self_attn.o_proj.delta_theta
# model.model.layers.7.self_attn.o_proj.delta_A
# model.model.layers.7.self_attn.o_proj.delta_B
# model.model.layers.7.self_attn.o_proj.delta_embedding
# model.model.layers.7.self_attn.rotary_emb
# model.model.layers.7.mlp.gate_proj.base_layer
# model.model.layers.7.mlp.gate_proj.delta_dropout.default
# model.model.layers.7.mlp.gate_proj.delta_theta
# model.model.layers.7.mlp.gate_proj.delta_A
# model.model.layers.7.mlp.gate_proj.delta_B
# model.model.layers.7.mlp.gate_proj.delta_embedding
# model.model.layers.7.mlp.up_proj.base_layer
# model.model.layers.7.mlp.up_proj.delta_dropout.default
# model.model.layers.7.mlp.up_proj.delta_theta
# model.model.layers.7.mlp.up_proj.delta_A
# model.model.layers.7.mlp.up_proj.delta_B
# model.model.layers.7.mlp.up_proj.delta_embedding
# model.model.layers.7.mlp.down_proj.base_layer
# model.model.layers.7.mlp.down_proj.delta_dropout.default
# model.model.layers.7.mlp.down_proj.delta_theta
# model.model.layers.7.mlp.down_proj.delta_A
# model.model.layers.7.mlp.down_proj.delta_B
# model.model.layers.7.mlp.down_proj.delta_embedding
# model.model.layers.7.mlp.act_fn
# model.model.layers.7.input_layernorm
# model.model.layers.7.post_attention_layernorm
# model.model.layers.8.self_attn.q_proj.base_layer
# model.model.layers.8.self_attn.q_proj.delta_dropout.default
# model.model.layers.8.self_attn.q_proj.delta_theta
# model.model.layers.8.self_attn.q_proj.delta_A
# model.model.layers.8.self_attn.q_proj.delta_B
# model.model.layers.8.self_attn.q_proj.delta_embedding
# model.model.layers.8.self_attn.k_proj.base_layer
# model.model.layers.8.self_attn.k_proj.delta_dropout.default
# model.model.layers.8.self_attn.k_proj.delta_theta
# model.model.layers.8.self_attn.k_proj.delta_A
# model.model.layers.8.self_attn.k_proj.delta_B
# model.model.layers.8.self_attn.k_proj.delta_embedding
# model.model.layers.8.self_attn.v_proj.base_layer
# model.model.layers.8.self_attn.v_proj.delta_dropout.default
# model.model.layers.8.self_attn.v_proj.delta_theta
# model.model.layers.8.self_attn.v_proj.delta_A
# model.model.layers.8.self_attn.v_proj.delta_B
# model.model.layers.8.self_attn.v_proj.delta_embedding
# model.model.layers.8.self_attn.o_proj.base_layer
# model.model.layers.8.self_attn.o_proj.delta_dropout.default
# model.model.layers.8.self_attn.o_proj.delta_theta
# model.model.layers.8.self_attn.o_proj.delta_A
# model.model.layers.8.self_attn.o_proj.delta_B
# model.model.layers.8.self_attn.o_proj.delta_embedding
# model.model.layers.8.self_attn.rotary_emb
# model.model.layers.8.mlp.gate_proj.base_layer
# model.model.layers.8.mlp.gate_proj.delta_dropout.default
# model.model.layers.8.mlp.gate_proj.delta_theta
# model.model.layers.8.mlp.gate_proj.delta_A
# model.model.layers.8.mlp.gate_proj.delta_B
# model.model.layers.8.mlp.gate_proj.delta_embedding
# model.model.layers.8.mlp.up_proj.base_layer
# model.model.layers.8.mlp.up_proj.delta_dropout.default
# model.model.layers.8.mlp.up_proj.delta_theta
# model.model.layers.8.mlp.up_proj.delta_A
# model.model.layers.8.mlp.up_proj.delta_B
# model.model.layers.8.mlp.up_proj.delta_embedding
# model.model.layers.8.mlp.down_proj.base_layer
# model.model.layers.8.mlp.down_proj.delta_dropout.default
# model.model.layers.8.mlp.down_proj.delta_theta
# model.model.layers.8.mlp.down_proj.delta_A
# model.model.layers.8.mlp.down_proj.delta_B
# model.model.layers.8.mlp.down_proj.delta_embedding
# model.model.layers.8.mlp.act_fn
# model.model.layers.8.input_layernorm
# model.model.layers.8.post_attention_layernorm
# model.model.layers.9.self_attn.q_proj.base_layer
# model.model.layers.9.self_attn.q_proj.delta_dropout.default
# model.model.layers.9.self_attn.q_proj.delta_theta
# model.model.layers.9.self_attn.q_proj.delta_A
# model.model.layers.9.self_attn.q_proj.delta_B
# model.model.layers.9.self_attn.q_proj.delta_embedding
# model.model.layers.9.self_attn.k_proj.base_layer
# model.model.layers.9.self_attn.k_proj.delta_dropout.default
# model.model.layers.9.self_attn.k_proj.delta_theta
# model.model.layers.9.self_attn.k_proj.delta_A
# model.model.layers.9.self_attn.k_proj.delta_B
# model.model.layers.9.self_attn.k_proj.delta_embedding
# model.model.layers.9.self_attn.v_proj.base_layer
# model.model.layers.9.self_attn.v_proj.delta_dropout.default
# model.model.layers.9.self_attn.v_proj.delta_theta
# model.model.layers.9.self_attn.v_proj.delta_A
# model.model.layers.9.self_attn.v_proj.delta_B
# model.model.layers.9.self_attn.v_proj.delta_embedding
# model.model.layers.9.self_attn.o_proj.base_layer
# model.model.layers.9.self_attn.o_proj.delta_dropout.default
# model.model.layers.9.self_attn.o_proj.delta_theta
# model.model.layers.9.self_attn.o_proj.delta_A
# model.model.layers.9.self_attn.o_proj.delta_B
# model.model.layers.9.self_attn.o_proj.delta_embedding
# model.model.layers.9.self_attn.rotary_emb
# model.model.layers.9.mlp.gate_proj.base_layer
# model.model.layers.9.mlp.gate_proj.delta_dropout.default
# model.model.layers.9.mlp.gate_proj.delta_theta
# model.model.layers.9.mlp.gate_proj.delta_A
# model.model.layers.9.mlp.gate_proj.delta_B
# model.model.layers.9.mlp.gate_proj.delta_embedding
# model.model.layers.9.mlp.up_proj.base_layer
# model.model.layers.9.mlp.up_proj.delta_dropout.default
# model.model.layers.9.mlp.up_proj.delta_theta
# model.model.layers.9.mlp.up_proj.delta_A
# model.model.layers.9.mlp.up_proj.delta_B
# model.model.layers.9.mlp.up_proj.delta_embedding
# model.model.layers.9.mlp.down_proj.base_layer
# model.model.layers.9.mlp.down_proj.delta_dropout.default
# model.model.layers.9.mlp.down_proj.delta_theta
# model.model.layers.9.mlp.down_proj.delta_A
# model.model.layers.9.mlp.down_proj.delta_B
# model.model.layers.9.mlp.down_proj.delta_embedding
# model.model.layers.9.mlp.act_fn
# model.model.layers.9.input_layernorm
# model.model.layers.9.post_attention_layernorm
# model.model.layers.10.self_attn.q_proj.base_layer
# model.model.layers.10.self_attn.q_proj.delta_dropout.default
# model.model.layers.10.self_attn.q_proj.delta_theta
# model.model.layers.10.self_attn.q_proj.delta_A
# model.model.layers.10.self_attn.q_proj.delta_B
# model.model.layers.10.self_attn.q_proj.delta_embedding
# model.model.layers.10.self_attn.k_proj.base_layer
# model.model.layers.10.self_attn.k_proj.delta_dropout.default
# model.model.layers.10.self_attn.k_proj.delta_theta
# model.model.layers.10.self_attn.k_proj.delta_A
# model.model.layers.10.self_attn.k_proj.delta_B
# model.model.layers.10.self_attn.k_proj.delta_embedding
# model.model.layers.10.self_attn.v_proj.base_layer
# model.model.layers.10.self_attn.v_proj.delta_dropout.default
# model.model.layers.10.self_attn.v_proj.delta_theta
# model.model.layers.10.self_attn.v_proj.delta_A
# model.model.layers.10.self_attn.v_proj.delta_B
# model.model.layers.10.self_attn.v_proj.delta_embedding
# model.model.layers.10.self_attn.o_proj.base_layer
# model.model.layers.10.self_attn.o_proj.delta_dropout.default
# model.model.layers.10.self_attn.o_proj.delta_theta
# model.model.layers.10.self_attn.o_proj.delta_A
# model.model.layers.10.self_attn.o_proj.delta_B
# model.model.layers.10.self_attn.o_proj.delta_embedding
# model.model.layers.10.self_attn.rotary_emb
# model.model.layers.10.mlp.gate_proj.base_layer
# model.model.layers.10.mlp.gate_proj.delta_dropout.default
# model.model.layers.10.mlp.gate_proj.delta_theta
# model.model.layers.10.mlp.gate_proj.delta_A
# model.model.layers.10.mlp.gate_proj.delta_B
# model.model.layers.10.mlp.gate_proj.delta_embedding
# model.model.layers.10.mlp.up_proj.base_layer
# model.model.layers.10.mlp.up_proj.delta_dropout.default
# model.model.layers.10.mlp.up_proj.delta_theta
# model.model.layers.10.mlp.up_proj.delta_A
# model.model.layers.10.mlp.up_proj.delta_B
# model.model.layers.10.mlp.up_proj.delta_embedding
# model.model.layers.10.mlp.down_proj.base_layer
# model.model.layers.10.mlp.down_proj.delta_dropout.default
# model.model.layers.10.mlp.down_proj.delta_theta
# model.model.layers.10.mlp.down_proj.delta_A
# model.model.layers.10.mlp.down_proj.delta_B
# model.model.layers.10.mlp.down_proj.delta_embedding
# model.model.layers.10.mlp.act_fn
# model.model.layers.10.input_layernorm
# model.model.layers.10.post_attention_layernorm
# model.model.layers.11.self_attn.q_proj.base_layer
# model.model.layers.11.self_attn.q_proj.delta_dropout.default
# model.model.layers.11.self_attn.q_proj.delta_theta
# model.model.layers.11.self_attn.q_proj.delta_A
# model.model.layers.11.self_attn.q_proj.delta_B
# model.model.layers.11.self_attn.q_proj.delta_embedding
# model.model.layers.11.self_attn.k_proj.base_layer
# model.model.layers.11.self_attn.k_proj.delta_dropout.default
# model.model.layers.11.self_attn.k_proj.delta_theta
# model.model.layers.11.self_attn.k_proj.delta_A
# model.model.layers.11.self_attn.k_proj.delta_B
# model.model.layers.11.self_attn.k_proj.delta_embedding
# model.model.layers.11.self_attn.v_proj.base_layer
# model.model.layers.11.self_attn.v_proj.delta_dropout.default
# model.model.layers.11.self_attn.v_proj.delta_theta
# model.model.layers.11.self_attn.v_proj.delta_A
# model.model.layers.11.self_attn.v_proj.delta_B
# model.model.layers.11.self_attn.v_proj.delta_embedding
# model.model.layers.11.self_attn.o_proj.base_layer
# model.model.layers.11.self_attn.o_proj.delta_dropout.default
# model.model.layers.11.self_attn.o_proj.delta_theta
# model.model.layers.11.self_attn.o_proj.delta_A
# model.model.layers.11.self_attn.o_proj.delta_B
# model.model.layers.11.self_attn.o_proj.delta_embedding
# model.model.layers.11.self_attn.rotary_emb
# model.model.layers.11.mlp.gate_proj.base_layer
# model.model.layers.11.mlp.gate_proj.delta_dropout.default
# model.model.layers.11.mlp.gate_proj.delta_theta
# model.model.layers.11.mlp.gate_proj.delta_A
# model.model.layers.11.mlp.gate_proj.delta_B
# model.model.layers.11.mlp.gate_proj.delta_embedding
# model.model.layers.11.mlp.up_proj.base_layer
# model.model.layers.11.mlp.up_proj.delta_dropout.default
# model.model.layers.11.mlp.up_proj.delta_theta
# model.model.layers.11.mlp.up_proj.delta_A
# model.model.layers.11.mlp.up_proj.delta_B
# model.model.layers.11.mlp.up_proj.delta_embedding
# model.model.layers.11.mlp.down_proj.base_layer
# model.model.layers.11.mlp.down_proj.delta_dropout.default
# model.model.layers.11.mlp.down_proj.delta_theta
# model.model.layers.11.mlp.down_proj.delta_A
# model.model.layers.11.mlp.down_proj.delta_B
# model.model.layers.11.mlp.down_proj.delta_embedding
# model.model.layers.11.mlp.act_fn
# model.model.layers.11.input_layernorm
# model.model.layers.11.post_attention_layernorm
# model.model.layers.12.self_attn.q_proj.base_layer
# model.model.layers.12.self_attn.q_proj.delta_dropout.default
# model.model.layers.12.self_attn.q_proj.delta_theta
# model.model.layers.12.self_attn.q_proj.delta_A
# model.model.layers.12.self_attn.q_proj.delta_B
# model.model.layers.12.self_attn.q_proj.delta_embedding
# model.model.layers.12.self_attn.k_proj.base_layer
# model.model.layers.12.self_attn.k_proj.delta_dropout.default
# model.model.layers.12.self_attn.k_proj.delta_theta
# model.model.layers.12.self_attn.k_proj.delta_A
# model.model.layers.12.self_attn.k_proj.delta_B
# model.model.layers.12.self_attn.k_proj.delta_embedding
# model.model.layers.12.self_attn.v_proj.base_layer
# model.model.layers.12.self_attn.v_proj.delta_dropout.default
# model.model.layers.12.self_attn.v_proj.delta_theta
# model.model.layers.12.self_attn.v_proj.delta_A
# model.model.layers.12.self_attn.v_proj.delta_B
# model.model.layers.12.self_attn.v_proj.delta_embedding
# model.model.layers.12.self_attn.o_proj.base_layer
# model.model.layers.12.self_attn.o_proj.delta_dropout.default
# model.model.layers.12.self_attn.o_proj.delta_theta
# model.model.layers.12.self_attn.o_proj.delta_A
# model.model.layers.12.self_attn.o_proj.delta_B
# model.model.layers.12.self_attn.o_proj.delta_embedding
# model.model.layers.12.self_attn.rotary_emb
# model.model.layers.12.mlp.gate_proj.base_layer
# model.model.layers.12.mlp.gate_proj.delta_dropout.default
# model.model.layers.12.mlp.gate_proj.delta_theta
# model.model.layers.12.mlp.gate_proj.delta_A
# model.model.layers.12.mlp.gate_proj.delta_B
# model.model.layers.12.mlp.gate_proj.delta_embedding
# model.model.layers.12.mlp.up_proj.base_layer
# model.model.layers.12.mlp.up_proj.delta_dropout.default
# model.model.layers.12.mlp.up_proj.delta_theta
# model.model.layers.12.mlp.up_proj.delta_A
# model.model.layers.12.mlp.up_proj.delta_B
# model.model.layers.12.mlp.up_proj.delta_embedding
# model.model.layers.12.mlp.down_proj.base_layer
# model.model.layers.12.mlp.down_proj.delta_dropout.default
# model.model.layers.12.mlp.down_proj.delta_theta
# model.model.layers.12.mlp.down_proj.delta_A
# model.model.layers.12.mlp.down_proj.delta_B
# model.model.layers.12.mlp.down_proj.delta_embedding
# model.model.layers.12.mlp.act_fn
# model.model.layers.12.input_layernorm
# model.model.layers.12.post_attention_layernorm
# model.model.layers.13.self_attn.q_proj.base_layer
# model.model.layers.13.self_attn.q_proj.delta_dropout.default
# model.model.layers.13.self_attn.q_proj.delta_theta
# model.model.layers.13.self_attn.q_proj.delta_A
# model.model.layers.13.self_attn.q_proj.delta_B
# model.model.layers.13.self_attn.q_proj.delta_embedding
# model.model.layers.13.self_attn.k_proj.base_layer
# model.model.layers.13.self_attn.k_proj.delta_dropout.default
# model.model.layers.13.self_attn.k_proj.delta_theta
# model.model.layers.13.self_attn.k_proj.delta_A
# model.model.layers.13.self_attn.k_proj.delta_B
# model.model.layers.13.self_attn.k_proj.delta_embedding
# model.model.layers.13.self_attn.v_proj.base_layer
# model.model.layers.13.self_attn.v_proj.delta_dropout.default
# model.model.layers.13.self_attn.v_proj.delta_theta
# model.model.layers.13.self_attn.v_proj.delta_A
# model.model.layers.13.self_attn.v_proj.delta_B
# model.model.layers.13.self_attn.v_proj.delta_embedding
# model.model.layers.13.self_attn.o_proj.base_layer
# model.model.layers.13.self_attn.o_proj.delta_dropout.default
# model.model.layers.13.self_attn.o_proj.delta_theta
# model.model.layers.13.self_attn.o_proj.delta_A
# model.model.layers.13.self_attn.o_proj.delta_B
# model.model.layers.13.self_attn.o_proj.delta_embedding
# model.model.layers.13.self_attn.rotary_emb
# model.model.layers.13.mlp.gate_proj.base_layer
# model.model.layers.13.mlp.gate_proj.delta_dropout.default
# model.model.layers.13.mlp.gate_proj.delta_theta
# model.model.layers.13.mlp.gate_proj.delta_A
# model.model.layers.13.mlp.gate_proj.delta_B
# model.model.layers.13.mlp.gate_proj.delta_embedding
# model.model.layers.13.mlp.up_proj.base_layer
# model.model.layers.13.mlp.up_proj.delta_dropout.default
# model.model.layers.13.mlp.up_proj.delta_theta
# model.model.layers.13.mlp.up_proj.delta_A
# model.model.layers.13.mlp.up_proj.delta_B
# model.model.layers.13.mlp.up_proj.delta_embedding
# model.model.layers.13.mlp.down_proj.base_layer
# model.model.layers.13.mlp.down_proj.delta_dropout.default
# model.model.layers.13.mlp.down_proj.delta_theta
# model.model.layers.13.mlp.down_proj.delta_A
# model.model.layers.13.mlp.down_proj.delta_B
# model.model.layers.13.mlp.down_proj.delta_embedding
# model.model.layers.13.mlp.act_fn
# model.model.layers.13.input_layernorm
# model.model.layers.13.post_attention_layernorm
# model.model.layers.14.self_attn.q_proj.base_layer
# model.model.layers.14.self_attn.q_proj.delta_dropout.default
# model.model.layers.14.self_attn.q_proj.delta_theta
# model.model.layers.14.self_attn.q_proj.delta_A
# model.model.layers.14.self_attn.q_proj.delta_B
# model.model.layers.14.self_attn.q_proj.delta_embedding
# model.model.layers.14.self_attn.k_proj.base_layer
# model.model.layers.14.self_attn.k_proj.delta_dropout.default
# model.model.layers.14.self_attn.k_proj.delta_theta
# model.model.layers.14.self_attn.k_proj.delta_A
# model.model.layers.14.self_attn.k_proj.delta_B
# model.model.layers.14.self_attn.k_proj.delta_embedding
# model.model.layers.14.self_attn.v_proj.base_layer
# model.model.layers.14.self_attn.v_proj.delta_dropout.default
# model.model.layers.14.self_attn.v_proj.delta_theta
# model.model.layers.14.self_attn.v_proj.delta_A
# model.model.layers.14.self_attn.v_proj.delta_B
# model.model.layers.14.self_attn.v_proj.delta_embedding
# model.model.layers.14.self_attn.o_proj.base_layer
# model.model.layers.14.self_attn.o_proj.delta_dropout.default
# model.model.layers.14.self_attn.o_proj.delta_theta
# model.model.layers.14.self_attn.o_proj.delta_A
# model.model.layers.14.self_attn.o_proj.delta_B
# model.model.layers.14.self_attn.o_proj.delta_embedding
# model.model.layers.14.self_attn.rotary_emb
# model.model.layers.14.mlp.gate_proj.base_layer
# model.model.layers.14.mlp.gate_proj.delta_dropout.default
# model.model.layers.14.mlp.gate_proj.delta_theta
# model.model.layers.14.mlp.gate_proj.delta_A
# model.model.layers.14.mlp.gate_proj.delta_B
# model.model.layers.14.mlp.gate_proj.delta_embedding
# model.model.layers.14.mlp.up_proj.base_layer
# model.model.layers.14.mlp.up_proj.delta_dropout.default
# model.model.layers.14.mlp.up_proj.delta_theta
# model.model.layers.14.mlp.up_proj.delta_A
# model.model.layers.14.mlp.up_proj.delta_B
# model.model.layers.14.mlp.up_proj.delta_embedding
# model.model.layers.14.mlp.down_proj.base_layer
# model.model.layers.14.mlp.down_proj.delta_dropout.default
# model.model.layers.14.mlp.down_proj.delta_theta
# model.model.layers.14.mlp.down_proj.delta_A
# model.model.layers.14.mlp.down_proj.delta_B
# model.model.layers.14.mlp.down_proj.delta_embedding
# model.model.layers.14.mlp.act_fn
# model.model.layers.14.input_layernorm
# model.model.layers.14.post_attention_layernorm
# model.model.layers.15.self_attn.q_proj.base_layer
# model.model.layers.15.self_attn.q_proj.delta_dropout.default
# model.model.layers.15.self_attn.q_proj.delta_theta
# model.model.layers.15.self_attn.q_proj.delta_A
# model.model.layers.15.self_attn.q_proj.delta_B
# model.model.layers.15.self_attn.q_proj.delta_embedding
# model.model.layers.15.self_attn.k_proj.base_layer
# model.model.layers.15.self_attn.k_proj.delta_dropout.default
# model.model.layers.15.self_attn.k_proj.delta_theta
# model.model.layers.15.self_attn.k_proj.delta_A
# model.model.layers.15.self_attn.k_proj.delta_B
# model.model.layers.15.self_attn.k_proj.delta_embedding
# model.model.layers.15.self_attn.v_proj.base_layer
# model.model.layers.15.self_attn.v_proj.delta_dropout.default
# model.model.layers.15.self_attn.v_proj.delta_theta
# model.model.layers.15.self_attn.v_proj.delta_A
# model.model.layers.15.self_attn.v_proj.delta_B
# model.model.layers.15.self_attn.v_proj.delta_embedding
# model.model.layers.15.self_attn.o_proj.base_layer
# model.model.layers.15.self_attn.o_proj.delta_dropout.default
# model.model.layers.15.self_attn.o_proj.delta_theta
# model.model.layers.15.self_attn.o_proj.delta_A
# model.model.layers.15.self_attn.o_proj.delta_B
# model.model.layers.15.self_attn.o_proj.delta_embedding
# model.model.layers.15.self_attn.rotary_emb
# model.model.layers.15.mlp.gate_proj.base_layer
# model.model.layers.15.mlp.gate_proj.delta_dropout.default
# model.model.layers.15.mlp.gate_proj.delta_theta
# model.model.layers.15.mlp.gate_proj.delta_A
# model.model.layers.15.mlp.gate_proj.delta_B
# model.model.layers.15.mlp.gate_proj.delta_embedding
# model.model.layers.15.mlp.up_proj.base_layer
# model.model.layers.15.mlp.up_proj.delta_dropout.default
# model.model.layers.15.mlp.up_proj.delta_theta
# model.model.layers.15.mlp.up_proj.delta_A
# model.model.layers.15.mlp.up_proj.delta_B
# model.model.layers.15.mlp.up_proj.delta_embedding
# model.model.layers.15.mlp.down_proj.base_layer
# model.model.layers.15.mlp.down_proj.delta_dropout.default
# model.model.layers.15.mlp.down_proj.delta_theta
# model.model.layers.15.mlp.down_proj.delta_A
# model.model.layers.15.mlp.down_proj.delta_B
# model.model.layers.15.mlp.down_proj.delta_embedding
# model.model.layers.15.mlp.act_fn
# model.model.layers.15.input_layernorm
# model.model.layers.15.post_attention_layernorm
# model.model.layers.16.self_attn.q_proj.base_layer
# model.model.layers.16.self_attn.q_proj.delta_dropout.default
# model.model.layers.16.self_attn.q_proj.delta_theta
# model.model.layers.16.self_attn.q_proj.delta_A
# model.model.layers.16.self_attn.q_proj.delta_B
# model.model.layers.16.self_attn.q_proj.delta_embedding
# model.model.layers.16.self_attn.k_proj.base_layer
# model.model.layers.16.self_attn.k_proj.delta_dropout.default
# model.model.layers.16.self_attn.k_proj.delta_theta
# model.model.layers.16.self_attn.k_proj.delta_A
# model.model.layers.16.self_attn.k_proj.delta_B
# model.model.layers.16.self_attn.k_proj.delta_embedding
# model.model.layers.16.self_attn.v_proj.base_layer
# model.model.layers.16.self_attn.v_proj.delta_dropout.default
# model.model.layers.16.self_attn.v_proj.delta_theta
# model.model.layers.16.self_attn.v_proj.delta_A
# model.model.layers.16.self_attn.v_proj.delta_B
# model.model.layers.16.self_attn.v_proj.delta_embedding
# model.model.layers.16.self_attn.o_proj.base_layer
# model.model.layers.16.self_attn.o_proj.delta_dropout.default
# model.model.layers.16.self_attn.o_proj.delta_theta
# model.model.layers.16.self_attn.o_proj.delta_A
# model.model.layers.16.self_attn.o_proj.delta_B
# model.model.layers.16.self_attn.o_proj.delta_embedding
# model.model.layers.16.self_attn.rotary_emb
# model.model.layers.16.mlp.gate_proj.base_layer
# model.model.layers.16.mlp.gate_proj.delta_dropout.default
# model.model.layers.16.mlp.gate_proj.delta_theta
# model.model.layers.16.mlp.gate_proj.delta_A
# model.model.layers.16.mlp.gate_proj.delta_B
# model.model.layers.16.mlp.gate_proj.delta_embedding
# model.model.layers.16.mlp.up_proj.base_layer
# model.model.layers.16.mlp.up_proj.delta_dropout.default
# model.model.layers.16.mlp.up_proj.delta_theta
# model.model.layers.16.mlp.up_proj.delta_A
# model.model.layers.16.mlp.up_proj.delta_B
# model.model.layers.16.mlp.up_proj.delta_embedding
# model.model.layers.16.mlp.down_proj.base_layer
# model.model.layers.16.mlp.down_proj.delta_dropout.default
# model.model.layers.16.mlp.down_proj.delta_theta
# model.model.layers.16.mlp.down_proj.delta_A
# model.model.layers.16.mlp.down_proj.delta_B
# model.model.layers.16.mlp.down_proj.delta_embedding
# model.model.layers.16.mlp.act_fn
# model.model.layers.16.input_layernorm
# model.model.layers.16.post_attention_layernorm
# model.model.layers.17.self_attn.q_proj.base_layer
# model.model.layers.17.self_attn.q_proj.delta_dropout.default
# model.model.layers.17.self_attn.q_proj.delta_theta
# model.model.layers.17.self_attn.q_proj.delta_A
# model.model.layers.17.self_attn.q_proj.delta_B
# model.model.layers.17.self_attn.q_proj.delta_embedding
# model.model.layers.17.self_attn.k_proj.base_layer
# model.model.layers.17.self_attn.k_proj.delta_dropout.default
# model.model.layers.17.self_attn.k_proj.delta_theta
# model.model.layers.17.self_attn.k_proj.delta_A
# model.model.layers.17.self_attn.k_proj.delta_B
# model.model.layers.17.self_attn.k_proj.delta_embedding
# model.model.layers.17.self_attn.v_proj.base_layer
# model.model.layers.17.self_attn.v_proj.delta_dropout.default
# model.model.layers.17.self_attn.v_proj.delta_theta
# model.model.layers.17.self_attn.v_proj.delta_A
# model.model.layers.17.self_attn.v_proj.delta_B
# model.model.layers.17.self_attn.v_proj.delta_embedding
# model.model.layers.17.self_attn.o_proj.base_layer
# model.model.layers.17.self_attn.o_proj.delta_dropout.default
# model.model.layers.17.self_attn.o_proj.delta_theta
# model.model.layers.17.self_attn.o_proj.delta_A
# model.model.layers.17.self_attn.o_proj.delta_B
# model.model.layers.17.self_attn.o_proj.delta_embedding
# model.model.layers.17.self_attn.rotary_emb
# model.model.layers.17.mlp.gate_proj.base_layer
# model.model.layers.17.mlp.gate_proj.delta_dropout.default
# model.model.layers.17.mlp.gate_proj.delta_theta
# model.model.layers.17.mlp.gate_proj.delta_A
# model.model.layers.17.mlp.gate_proj.delta_B
# model.model.layers.17.mlp.gate_proj.delta_embedding
# model.model.layers.17.mlp.up_proj.base_layer
# model.model.layers.17.mlp.up_proj.delta_dropout.default
# model.model.layers.17.mlp.up_proj.delta_theta
# model.model.layers.17.mlp.up_proj.delta_A
# model.model.layers.17.mlp.up_proj.delta_B
# model.model.layers.17.mlp.up_proj.delta_embedding
# model.model.layers.17.mlp.down_proj.base_layer
# model.model.layers.17.mlp.down_proj.delta_dropout.default
# model.model.layers.17.mlp.down_proj.delta_theta
# model.model.layers.17.mlp.down_proj.delta_A
# model.model.layers.17.mlp.down_proj.delta_B
# model.model.layers.17.mlp.down_proj.delta_embedding
# model.model.layers.17.mlp.act_fn
# model.model.layers.17.input_layernorm
# model.model.layers.17.post_attention_layernorm
# model.model.layers.18.self_attn.q_proj.base_layer
# model.model.layers.18.self_attn.q_proj.delta_dropout.default
# model.model.layers.18.self_attn.q_proj.delta_theta
# model.model.layers.18.self_attn.q_proj.delta_A
# model.model.layers.18.self_attn.q_proj.delta_B
# model.model.layers.18.self_attn.q_proj.delta_embedding
# model.model.layers.18.self_attn.k_proj.base_layer
# model.model.layers.18.self_attn.k_proj.delta_dropout.default
# model.model.layers.18.self_attn.k_proj.delta_theta
# model.model.layers.18.self_attn.k_proj.delta_A
# model.model.layers.18.self_attn.k_proj.delta_B
# model.model.layers.18.self_attn.k_proj.delta_embedding
# model.model.layers.18.self_attn.v_proj.base_layer
# model.model.layers.18.self_attn.v_proj.delta_dropout.default
# model.model.layers.18.self_attn.v_proj.delta_theta
# model.model.layers.18.self_attn.v_proj.delta_A
# model.model.layers.18.self_attn.v_proj.delta_B
# model.model.layers.18.self_attn.v_proj.delta_embedding
# model.model.layers.18.self_attn.o_proj.base_layer
# model.model.layers.18.self_attn.o_proj.delta_dropout.default
# model.model.layers.18.self_attn.o_proj.delta_theta
# model.model.layers.18.self_attn.o_proj.delta_A
# model.model.layers.18.self_attn.o_proj.delta_B
# model.model.layers.18.self_attn.o_proj.delta_embedding
# model.model.layers.18.self_attn.rotary_emb
# model.model.layers.18.mlp.gate_proj.base_layer
# model.model.layers.18.mlp.gate_proj.delta_dropout.default
# model.model.layers.18.mlp.gate_proj.delta_theta
# model.model.layers.18.mlp.gate_proj.delta_A
# model.model.layers.18.mlp.gate_proj.delta_B
# model.model.layers.18.mlp.gate_proj.delta_embedding
# model.model.layers.18.mlp.up_proj.base_layer
# model.model.layers.18.mlp.up_proj.delta_dropout.default
# model.model.layers.18.mlp.up_proj.delta_theta
# model.model.layers.18.mlp.up_proj.delta_A
# model.model.layers.18.mlp.up_proj.delta_B
# model.model.layers.18.mlp.up_proj.delta_embedding
# model.model.layers.18.mlp.down_proj.base_layer
# model.model.layers.18.mlp.down_proj.delta_dropout.default
# model.model.layers.18.mlp.down_proj.delta_theta
# model.model.layers.18.mlp.down_proj.delta_A
# model.model.layers.18.mlp.down_proj.delta_B
# model.model.layers.18.mlp.down_proj.delta_embedding
# model.model.layers.18.mlp.act_fn
# model.model.layers.18.input_layernorm
# model.model.layers.18.post_attention_layernorm
# model.model.layers.19.self_attn.q_proj.base_layer
# model.model.layers.19.self_attn.q_proj.delta_dropout.default
# model.model.layers.19.self_attn.q_proj.delta_theta
# model.model.layers.19.self_attn.q_proj.delta_A
# model.model.layers.19.self_attn.q_proj.delta_B
# model.model.layers.19.self_attn.q_proj.delta_embedding
# model.model.layers.19.self_attn.k_proj.base_layer
# model.model.layers.19.self_attn.k_proj.delta_dropout.default
# model.model.layers.19.self_attn.k_proj.delta_theta
# model.model.layers.19.self_attn.k_proj.delta_A
# model.model.layers.19.self_attn.k_proj.delta_B
# model.model.layers.19.self_attn.k_proj.delta_embedding
# model.model.layers.19.self_attn.v_proj.base_layer
# model.model.layers.19.self_attn.v_proj.delta_dropout.default
# model.model.layers.19.self_attn.v_proj.delta_theta
# model.model.layers.19.self_attn.v_proj.delta_A
# model.model.layers.19.self_attn.v_proj.delta_B
# model.model.layers.19.self_attn.v_proj.delta_embedding
# model.model.layers.19.self_attn.o_proj.base_layer
# model.model.layers.19.self_attn.o_proj.delta_dropout.default
# model.model.layers.19.self_attn.o_proj.delta_theta
# model.model.layers.19.self_attn.o_proj.delta_A
# model.model.layers.19.self_attn.o_proj.delta_B
# model.model.layers.19.self_attn.o_proj.delta_embedding
# model.model.layers.19.self_attn.rotary_emb
# model.model.layers.19.mlp.gate_proj.base_layer
# model.model.layers.19.mlp.gate_proj.delta_dropout.default
# model.model.layers.19.mlp.gate_proj.delta_theta
# model.model.layers.19.mlp.gate_proj.delta_A
# model.model.layers.19.mlp.gate_proj.delta_B
# model.model.layers.19.mlp.gate_proj.delta_embedding
# model.model.layers.19.mlp.up_proj.base_layer
# model.model.layers.19.mlp.up_proj.delta_dropout.default
# model.model.layers.19.mlp.up_proj.delta_theta
# model.model.layers.19.mlp.up_proj.delta_A
# model.model.layers.19.mlp.up_proj.delta_B
# model.model.layers.19.mlp.up_proj.delta_embedding
# model.model.layers.19.mlp.down_proj.base_layer
# model.model.layers.19.mlp.down_proj.delta_dropout.default
# model.model.layers.19.mlp.down_proj.delta_theta
# model.model.layers.19.mlp.down_proj.delta_A
# model.model.layers.19.mlp.down_proj.delta_B
# model.model.layers.19.mlp.down_proj.delta_embedding
# model.model.layers.19.mlp.act_fn
# model.model.layers.19.input_layernorm
# model.model.layers.19.post_attention_layernorm
# model.model.layers.20.self_attn.q_proj.base_layer
# model.model.layers.20.self_attn.q_proj.delta_dropout.default
# model.model.layers.20.self_attn.q_proj.delta_theta
# model.model.layers.20.self_attn.q_proj.delta_A
# model.model.layers.20.self_attn.q_proj.delta_B
# model.model.layers.20.self_attn.q_proj.delta_embedding
# model.model.layers.20.self_attn.k_proj.base_layer
# model.model.layers.20.self_attn.k_proj.delta_dropout.default
# model.model.layers.20.self_attn.k_proj.delta_theta
# model.model.layers.20.self_attn.k_proj.delta_A
# model.model.layers.20.self_attn.k_proj.delta_B
# model.model.layers.20.self_attn.k_proj.delta_embedding
# model.model.layers.20.self_attn.v_proj.base_layer
# model.model.layers.20.self_attn.v_proj.delta_dropout.default
# model.model.layers.20.self_attn.v_proj.delta_theta
# model.model.layers.20.self_attn.v_proj.delta_A
# model.model.layers.20.self_attn.v_proj.delta_B
# model.model.layers.20.self_attn.v_proj.delta_embedding
# model.model.layers.20.self_attn.o_proj.base_layer
# model.model.layers.20.self_attn.o_proj.delta_dropout.default
# model.model.layers.20.self_attn.o_proj.delta_theta
# model.model.layers.20.self_attn.o_proj.delta_A
# model.model.layers.20.self_attn.o_proj.delta_B
# model.model.layers.20.self_attn.o_proj.delta_embedding
# model.model.layers.20.self_attn.rotary_emb
# model.model.layers.20.mlp.gate_proj.base_layer
# model.model.layers.20.mlp.gate_proj.delta_dropout.default
# model.model.layers.20.mlp.gate_proj.delta_theta
# model.model.layers.20.mlp.gate_proj.delta_A
# model.model.layers.20.mlp.gate_proj.delta_B
# model.model.layers.20.mlp.gate_proj.delta_embedding
# model.model.layers.20.mlp.up_proj.base_layer
# model.model.layers.20.mlp.up_proj.delta_dropout.default
# model.model.layers.20.mlp.up_proj.delta_theta
# model.model.layers.20.mlp.up_proj.delta_A
# model.model.layers.20.mlp.up_proj.delta_B
# model.model.layers.20.mlp.up_proj.delta_embedding
# model.model.layers.20.mlp.down_proj.base_layer
# model.model.layers.20.mlp.down_proj.delta_dropout.default
# model.model.layers.20.mlp.down_proj.delta_theta
# model.model.layers.20.mlp.down_proj.delta_A
# model.model.layers.20.mlp.down_proj.delta_B
# model.model.layers.20.mlp.down_proj.delta_embedding
# model.model.layers.20.mlp.act_fn
# model.model.layers.20.input_layernorm
# model.model.layers.20.post_attention_layernorm
# model.model.layers.21.self_attn.q_proj.base_layer
# model.model.layers.21.self_attn.q_proj.delta_dropout.default
# model.model.layers.21.self_attn.q_proj.delta_theta
# model.model.layers.21.self_attn.q_proj.delta_A
# model.model.layers.21.self_attn.q_proj.delta_B
# model.model.layers.21.self_attn.q_proj.delta_embedding
# model.model.layers.21.self_attn.k_proj.base_layer
# model.model.layers.21.self_attn.k_proj.delta_dropout.default
# model.model.layers.21.self_attn.k_proj.delta_theta
# model.model.layers.21.self_attn.k_proj.delta_A
# model.model.layers.21.self_attn.k_proj.delta_B
# model.model.layers.21.self_attn.k_proj.delta_embedding
# model.model.layers.21.self_attn.v_proj.base_layer
# model.model.layers.21.self_attn.v_proj.delta_dropout.default
# model.model.layers.21.self_attn.v_proj.delta_theta
# model.model.layers.21.self_attn.v_proj.delta_A
# model.model.layers.21.self_attn.v_proj.delta_B
# model.model.layers.21.self_attn.v_proj.delta_embedding
# model.model.layers.21.self_attn.o_proj.base_layer
# model.model.layers.21.self_attn.o_proj.delta_dropout.default
# model.model.layers.21.self_attn.o_proj.delta_theta
# model.model.layers.21.self_attn.o_proj.delta_A
# model.model.layers.21.self_attn.o_proj.delta_B
# model.model.layers.21.self_attn.o_proj.delta_embedding
# model.model.layers.21.self_attn.rotary_emb
# model.model.layers.21.mlp.gate_proj.base_layer
# model.model.layers.21.mlp.gate_proj.delta_dropout.default
# model.model.layers.21.mlp.gate_proj.delta_theta
# model.model.layers.21.mlp.gate_proj.delta_A
# model.model.layers.21.mlp.gate_proj.delta_B
# model.model.layers.21.mlp.gate_proj.delta_embedding
# model.model.layers.21.mlp.up_proj.base_layer
# model.model.layers.21.mlp.up_proj.delta_dropout.default
# model.model.layers.21.mlp.up_proj.delta_theta
# model.model.layers.21.mlp.up_proj.delta_A
# model.model.layers.21.mlp.up_proj.delta_B
# model.model.layers.21.mlp.up_proj.delta_embedding
# model.model.layers.21.mlp.down_proj.base_layer
# model.model.layers.21.mlp.down_proj.delta_dropout.default
# model.model.layers.21.mlp.down_proj.delta_theta
# model.model.layers.21.mlp.down_proj.delta_A
# model.model.layers.21.mlp.down_proj.delta_B
# model.model.layers.21.mlp.down_proj.delta_embedding
# model.model.layers.21.mlp.act_fn
# model.model.layers.21.input_layernorm
# model.model.layers.21.post_attention_layernorm
# model.model.layers.22.self_attn.q_proj.base_layer
# model.model.layers.22.self_attn.q_proj.delta_dropout.default
# model.model.layers.22.self_attn.q_proj.delta_theta
# model.model.layers.22.self_attn.q_proj.delta_A
# model.model.layers.22.self_attn.q_proj.delta_B
# model.model.layers.22.self_attn.q_proj.delta_embedding
# model.model.layers.22.self_attn.k_proj.base_layer
# model.model.layers.22.self_attn.k_proj.delta_dropout.default
# model.model.layers.22.self_attn.k_proj.delta_theta
# model.model.layers.22.self_attn.k_proj.delta_A
# model.model.layers.22.self_attn.k_proj.delta_B
# model.model.layers.22.self_attn.k_proj.delta_embedding
# model.model.layers.22.self_attn.v_proj.base_layer
# model.model.layers.22.self_attn.v_proj.delta_dropout.default
# model.model.layers.22.self_attn.v_proj.delta_theta
# model.model.layers.22.self_attn.v_proj.delta_A
# model.model.layers.22.self_attn.v_proj.delta_B
# model.model.layers.22.self_attn.v_proj.delta_embedding
# model.model.layers.22.self_attn.o_proj.base_layer
# model.model.layers.22.self_attn.o_proj.delta_dropout.default
# model.model.layers.22.self_attn.o_proj.delta_theta
# model.model.layers.22.self_attn.o_proj.delta_A
# model.model.layers.22.self_attn.o_proj.delta_B
# model.model.layers.22.self_attn.o_proj.delta_embedding
# model.model.layers.22.self_attn.rotary_emb
# model.model.layers.22.mlp.gate_proj.base_layer
# model.model.layers.22.mlp.gate_proj.delta_dropout.default
# model.model.layers.22.mlp.gate_proj.delta_theta
# model.model.layers.22.mlp.gate_proj.delta_A
# model.model.layers.22.mlp.gate_proj.delta_B
# model.model.layers.22.mlp.gate_proj.delta_embedding
# model.model.layers.22.mlp.up_proj.base_layer
# model.model.layers.22.mlp.up_proj.delta_dropout.default
# model.model.layers.22.mlp.up_proj.delta_theta
# model.model.layers.22.mlp.up_proj.delta_A
# model.model.layers.22.mlp.up_proj.delta_B
# model.model.layers.22.mlp.up_proj.delta_embedding
# model.model.layers.22.mlp.down_proj.base_layer
# model.model.layers.22.mlp.down_proj.delta_dropout.default
# model.model.layers.22.mlp.down_proj.delta_theta
# model.model.layers.22.mlp.down_proj.delta_A
# model.model.layers.22.mlp.down_proj.delta_B
# model.model.layers.22.mlp.down_proj.delta_embedding
# model.model.layers.22.mlp.act_fn
# model.model.layers.22.input_layernorm
# model.model.layers.22.post_attention_layernorm
# model.model.layers.23.self_attn.q_proj.base_layer
# model.model.layers.23.self_attn.q_proj.delta_dropout.default
# model.model.layers.23.self_attn.q_proj.delta_theta
# model.model.layers.23.self_attn.q_proj.delta_A
# model.model.layers.23.self_attn.q_proj.delta_B
# model.model.layers.23.self_attn.q_proj.delta_embedding
# model.model.layers.23.self_attn.k_proj.base_layer
# model.model.layers.23.self_attn.k_proj.delta_dropout.default
# model.model.layers.23.self_attn.k_proj.delta_theta
# model.model.layers.23.self_attn.k_proj.delta_A
# model.model.layers.23.self_attn.k_proj.delta_B
# model.model.layers.23.self_attn.k_proj.delta_embedding
# model.model.layers.23.self_attn.v_proj.base_layer
# model.model.layers.23.self_attn.v_proj.delta_dropout.default
# model.model.layers.23.self_attn.v_proj.delta_theta
# model.model.layers.23.self_attn.v_proj.delta_A
# model.model.layers.23.self_attn.v_proj.delta_B
# model.model.layers.23.self_attn.v_proj.delta_embedding
# model.model.layers.23.self_attn.o_proj.base_layer
# model.model.layers.23.self_attn.o_proj.delta_dropout.default
# model.model.layers.23.self_attn.o_proj.delta_theta
# model.model.layers.23.self_attn.o_proj.delta_A
# model.model.layers.23.self_attn.o_proj.delta_B
# model.model.layers.23.self_attn.o_proj.delta_embedding
# model.model.layers.23.self_attn.rotary_emb
# model.model.layers.23.mlp.gate_proj.base_layer
# model.model.layers.23.mlp.gate_proj.delta_dropout.default
# model.model.layers.23.mlp.gate_proj.delta_theta
# model.model.layers.23.mlp.gate_proj.delta_A
# model.model.layers.23.mlp.gate_proj.delta_B
# model.model.layers.23.mlp.gate_proj.delta_embedding
# model.model.layers.23.mlp.up_proj.base_layer
# model.model.layers.23.mlp.up_proj.delta_dropout.default
# model.model.layers.23.mlp.up_proj.delta_theta
# model.model.layers.23.mlp.up_proj.delta_A
# model.model.layers.23.mlp.up_proj.delta_B
# model.model.layers.23.mlp.up_proj.delta_embedding
# model.model.layers.23.mlp.down_proj.base_layer
# model.model.layers.23.mlp.down_proj.delta_dropout.default
# model.model.layers.23.mlp.down_proj.delta_theta
# model.model.layers.23.mlp.down_proj.delta_A
# model.model.layers.23.mlp.down_proj.delta_B
# model.model.layers.23.mlp.down_proj.delta_embedding
# model.model.layers.23.mlp.act_fn
# model.model.layers.23.input_layernorm
# model.model.layers.23.post_attention_layernorm
# model.model.norm
# model.lm_head
